# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\anush\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\anush\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\anush\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     C:\Users\anush\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# ...

# %%
# Step 1: Import required libraries
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Step 2: Sample text document
text = "Data science is about finding useful information in a sea of numbers. It helps us understand what’s really happening and make better decisions. A data scientist’s job is to ask smart questions and look for patterns in the data. In the end, it's about turning complex data into something clear and helpful."
print("Original text:",text)
# Out:
# Original text: Data science is about finding useful information in a sea of numbers. It helps us understand what’s really happening and make better decisions. A data scientist’s job is to ask smart questions and look for patterns in the data. In the end, it's about turning complex data into something clear and helpful.

# %%
# Step 3: Tokenization
tokens = word_tokenize(text)
print("Tokens:",tokens)
# Out:
# Tokens: ['Data', 'science', 'is', 'about', 'finding', 'useful', 'information', 'in', 'a', 'sea', 'of', 'numbers', '.', 'It', 'helps', 'us', 'understand', 'what', '’', 's', 'really', 'happening', 'and', 'make', 'better', 'decisions', '.', 'A', 'data', 'scientist', '’', 's', 'job', 'is', 'to', 'ask', 'smart', 'questions', 'and', 'look', 'for', 'patterns', 'in', 'the', 'data', '.', 'In', 'the', 'end', ',', 'it', "'s", 'about', 'turning', 'complex', 'data', 'into', 'something', 'clear', 'and', 'helpful', '.']

# %%
# Step 4: POS Tagging
pos_tags = nltk.pos_tag(tokens)
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('Data', 'NNP'), ('science', 'NN'), ('is', 'VBZ'), ('about', 'IN'), ('finding', 'VBG'), ('useful', 'JJ'), ('information', 'NN'), ('in', 'IN'), ('a', 'DT'), ('sea', 'NN'), ('of', 'IN'), ('numbers', 'NNS'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('us', 'PRP'), ('understand', 'VB'), ('what', 'WP'), ('’', 'NNP'), ('s', 'VBD'), ('really', 'RB'), ('happening', 'VBG'), ('and', 'CC'), ('make', 'VB'), ('better', 'JJR'), ('decisions', 'NNS'), ('.', '.'), ('A', 'DT'), ('data', 'NN'), ('scientist', 'NN'), ('’', 'NNP'), ('s', 'NN'), ('job', 'NN'), ('is', 'VBZ'), ('to', 'TO'), ('ask', 'VB'), ('smart', 'JJ'), ('questions', 'NNS'), ('and', 'CC'), ('look', 'NN'), ('for', 'IN'), ('patterns', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('data', 'NN'), ('.', '.'), ('In', 'IN'), ('the', 'DT'), ('end', 'NN'), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('about', 'IN'), ('turning', 'VBG'), ('complex', 'JJ'), ('data', 'NNS'), ('into', 'IN'), ('something', 'NN'), ('clear', 'JJ'), ('and', 'CC'), ('hel
# ...

# %%
# Step 5: Stop words removal
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("Filtered Tokens:", filtered_tokens)
# Out:
# Filtered Tokens: ['Data', 'science', 'finding', 'useful', 'information', 'sea', 'numbers', '.', 'helps', 'us', 'understand', '’', 'really', 'happening', 'make', 'better', 'decisions', '.', 'data', 'scientist', '’', 'job', 'ask', 'smart', 'questions', 'look', 'patterns', 'data', '.', 'end', ',', "'s", 'turning', 'complex', 'data', 'something', 'clear', 'helpful', '.']

# %%
# Step 6: Stemming and Lemmatization
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("Stemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['data', 'scienc', 'find', 'use', 'inform', 'sea', 'number', '.', 'help', 'us', 'understand', '’', 'realli', 'happen', 'make', 'better', 'decis', '.', 'data', 'scientist', '’', 'job', 'ask', 'smart', 'question', 'look', 'pattern', 'data', '.', 'end', ',', "'s", 'turn', 'complex', 'data', 'someth', 'clear', 'help', '.']

# %%
print("Lemmatized Words:", lemmatized_words)
# Out:
# Lemmatized Words: ['Data', 'science', 'finding', 'useful', 'information', 'sea', 'number', '.', 'help', 'u', 'understand', '’', 'really', 'happening', 'make', 'better', 'decision', '.', 'data', 'scientist', '’', 'job', 'ask', 'smart', 'question', 'look', 'pattern', 'data', '.', 'end', ',', "'s", 'turning', 'complex', 'data', 'something', 'clear', 'helpful', '.']

# %%
# Step 7: TF-IDF representation
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([" ".join(lemmatized_words)])
print("TF-IDF Matrix:\n", tfidf_matrix.toarray())
# Out:
# TF-IDF Matrix:
#  [[0.15430335 0.15430335 0.15430335 0.15430335 0.6172134  0.15430335
#   0.15430335 0.15430335 0.15430335 0.15430335 0.15430335 0.15430335
#   0.15430335 0.15430335 0.15430335 0.15430335 0.15430335 0.15430335
#   0.15430335 0.15430335 0.15430335 0.15430335 0.15430335 0.15430335
#   0.15430335 0.15430335 0.15430335]]
